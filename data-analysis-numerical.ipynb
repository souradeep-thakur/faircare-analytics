# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

sns.set_style("whitegrid")

# %%
data = pd.read_csv('data/dataset_clean.csv')
data['target'] = (data['readmitted'] != 'NO').astype('int')

# %%
data_eda_num = data.select_dtypes(include='int64')
data_eda_num = data_eda_num.drop(columns=['patient_nbr', 'encounter_id'])

# %%
x_var_name = 'admission_type_id'

data_eda_num['readmitted_freq'] = data_eda_num.groupby(x_var_name)['target'].transform('sum')
plot_data = data_eda_num.melt(id_vars=x_var_name, value_vars='readmitted_freq', value_name='y')
data_eda_num = data_eda_num.drop(columns = 'readmitted_freq')
plot_data = plot_data.drop(columns='variable')
plot_data = plot_data.drop_duplicates(subset=[x_var_name, 'y']).sort_values(x_var_name).reset_index(drop=True)

plt.figure()

plt.plot(plot_data[x_var_name],
         plot_data['y'],
         'b',
         linewidth=1)

plt.xlabel(x_var_name, fontsize=14)
plt.ylabel("Readmission frequency", fontsize=14)

plt.show()

del plot_data
del x_var_name

# %%
x_var_name = 'discharge_disposition_id'

data_eda_num['readmitted_freq'] = data_eda_num.groupby(x_var_name)['target'].transform('sum')
plot_data = data_eda_num.melt(id_vars=x_var_name, value_vars='readmitted_freq', value_name='y')
data_eda_num = data_eda_num.drop(columns = 'readmitted_freq')
plot_data = plot_data.drop(columns='variable')
plot_data = plot_data.drop_duplicates(subset=[x_var_name, 'y']).sort_values(x_var_name).reset_index(drop=True)

plt.figure()

plt.plot(plot_data[x_var_name],
         plot_data['y'],
         'r',
         linewidth=1)

plt.xlabel(x_var_name, fontsize=14)
plt.ylabel("Readmission frequency", fontsize=14)

plt.show()

del plot_data
del x_var_name

# %%
x_var_name = 'admission_source_id'

data_eda_num['readmitted_freq'] = data_eda_num.groupby(x_var_name)['target'].transform('sum')
plot_data = data_eda_num.melt(id_vars=x_var_name, value_vars='readmitted_freq', value_name='y')
data_eda_num = data_eda_num.drop(columns = 'readmitted_freq')
plot_data = plot_data.drop(columns='variable')
plot_data = plot_data.drop_duplicates(subset=[x_var_name, 'y']).sort_values(x_var_name).reset_index(drop=True)

plt.figure()

plt.plot(plot_data[x_var_name],
         plot_data['y'],
         'g',
         linewidth=1)

plt.xlabel(x_var_name, fontsize=14)
plt.ylabel("Readmission frequency", fontsize=14)

plt.show()

del plot_data
del x_var_name

# %%
x_var_name = 'time_in_hospital'

data_eda_num['readmitted_freq'] = data_eda_num.groupby(x_var_name)['target'].transform('sum')
plot_data = data_eda_num.melt(id_vars=x_var_name, value_vars='readmitted_freq', value_name='y')
data_eda_num = data_eda_num.drop(columns = 'readmitted_freq')
plot_data = plot_data.drop(columns='variable')
plot_data = plot_data.drop_duplicates(subset=[x_var_name, 'y']).sort_values(x_var_name).reset_index(drop=True)

plt.figure()

plt.plot(plot_data[x_var_name],
         plot_data['y'],
         'c',
         linewidth=1)

plt.xlabel(x_var_name, fontsize=14)
plt.ylabel("Readmission frequency", fontsize=14)

plt.show()

del plot_data
del x_var_name

# %%
x_var_name = 'num_lab_procedures'

data_eda_num['readmitted_freq'] = data_eda_num.groupby(x_var_name)['target'].transform('sum')
plot_data = data_eda_num.melt(id_vars=x_var_name, value_vars='readmitted_freq', value_name='y')
data_eda_num = data_eda_num.drop(columns = 'readmitted_freq')
plot_data = plot_data.drop(columns='variable')
plot_data = plot_data.drop_duplicates(subset=[x_var_name, 'y']).sort_values(x_var_name).reset_index(drop=True)

plt.figure()

plt.plot(plot_data[x_var_name],
         plot_data['y'],
         'm',
         linewidth=1)

plt.xlabel(x_var_name, fontsize=14)
plt.ylabel("Readmission frequency", fontsize=14)

plt.show()

del plot_data
del x_var_name

# %%
x_var_name = 'num_procedures'

data_eda_num['readmitted_freq'] = data_eda_num.groupby(x_var_name)['target'].transform('sum')
plot_data = data_eda_num.melt(id_vars=x_var_name, value_vars='readmitted_freq', value_name='y')
data_eda_num = data_eda_num.drop(columns = 'readmitted_freq')
plot_data = plot_data.drop(columns='variable')
plot_data = plot_data.drop_duplicates(subset=[x_var_name, 'y']).sort_values(x_var_name).reset_index(drop=True)

plt.figure()

plt.plot(plot_data[x_var_name],
         plot_data['y'],
         'y',
         linewidth=1)

plt.xlabel(x_var_name, fontsize=14)
plt.ylabel("Readmission frequency", fontsize=14)

plt.show()

del plot_data
del x_var_name

# %%
x_var_name = 'num_medications'

data_eda_num['readmitted_freq'] = data_eda_num.groupby(x_var_name)['target'].transform('sum')
plot_data = data_eda_num.melt(id_vars=x_var_name, value_vars='readmitted_freq', value_name='y')
data_eda_num = data_eda_num.drop(columns = 'readmitted_freq')
plot_data = plot_data.drop(columns='variable')
plot_data = plot_data.drop_duplicates(subset=[x_var_name, 'y']).sort_values(x_var_name).reset_index(drop=True)

plt.figure()

plt.plot(plot_data[x_var_name],
         plot_data['y'],
         'k',
         linewidth=1)

plt.xlabel(x_var_name, fontsize=14)
plt.ylabel("Readmission frequency", fontsize=14)

plt.show()

del plot_data
del x_var_name

# %%
x_var_name = 'number_outpatient'

data_eda_num['readmitted_freq'] = data_eda_num.groupby(x_var_name)['target'].transform('sum')
plot_data = data_eda_num.melt(id_vars=x_var_name, value_vars='readmitted_freq', value_name='y')
data_eda_num = data_eda_num.drop(columns = 'readmitted_freq')
plot_data = plot_data.drop(columns='variable')
plot_data = plot_data.drop_duplicates(subset=[x_var_name, 'y']).sort_values(x_var_name).reset_index(drop=True)

plt.figure()

plt.plot(plot_data[x_var_name],
         plot_data['y'],
         'b',
         linewidth=1)

plt.xlabel(x_var_name, fontsize=14)
plt.ylabel("Readmission frequency", fontsize=14)

plt.show()

del plot_data
del x_var_name

# %%
x_var_name = 'number_emergency'

data_eda_num['readmitted_freq'] = data_eda_num.groupby(x_var_name)['target'].transform('sum')
plot_data = data_eda_num.melt(id_vars=x_var_name, value_vars='readmitted_freq', value_name='y')
data_eda_num = data_eda_num.drop(columns = 'readmitted_freq')
plot_data = plot_data.drop(columns='variable')
plot_data = plot_data.drop_duplicates(subset=[x_var_name, 'y']).sort_values(x_var_name).reset_index(drop=True)

plt.figure()

plt.plot(plot_data[x_var_name],
         plot_data['y'],
         'r',
         linewidth=1)

plt.xlabel(x_var_name, fontsize=14)
plt.ylabel("Readmission frequency", fontsize=14)

plt.show()

del plot_data
del x_var_name

# %%
x_var_name = 'number_inpatient'

data_eda_num['readmitted_freq'] = data_eda_num.groupby(x_var_name)['target'].transform('sum')
plot_data = data_eda_num.melt(id_vars=x_var_name, value_vars='readmitted_freq', value_name='y')
data_eda_num = data_eda_num.drop(columns = 'readmitted_freq')
plot_data = plot_data.drop(columns='variable')
plot_data = plot_data.drop_duplicates(subset=[x_var_name, 'y']).sort_values(x_var_name).reset_index(drop=True)

plt.figure()

plt.plot(plot_data[x_var_name],
         plot_data['y'],
         'g',
         linewidth=1)

plt.xlabel(x_var_name, fontsize=14)
plt.ylabel("Readmission frequency", fontsize=14)

plt.show()

del plot_data
del x_var_name

# %%
x_var_name = 'number_diagnoses'

data_eda_num['readmitted_freq'] = data_eda_num.groupby(x_var_name)['target'].transform('sum')
plot_data = data_eda_num.melt(id_vars=x_var_name, value_vars='readmitted_freq', value_name='y')
data_eda_num = data_eda_num.drop(columns = 'readmitted_freq')
plot_data = plot_data.drop(columns='variable')
plot_data = plot_data.drop_duplicates(subset=[x_var_name, 'y']).sort_values(x_var_name).reset_index(drop=True)

plt.figure()

plt.plot(plot_data[x_var_name],
         plot_data['y'],
         'm',
         linewidth=1)

plt.xlabel(x_var_name, fontsize=14)
plt.ylabel("Readmission frequency", fontsize=14)

plt.show()

del plot_data
del x_var_name
