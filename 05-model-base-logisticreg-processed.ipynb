# %% [markdown]
# # Logistic regression

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import csv

sns.set_style("whitegrid")

# %%
import pandas as pd

# Load the CSV using the absolute path
data = pd.read_csv('./data/data_processed.csv')

# Check the first few rows to confirm
print(data.head())
# Out:
#               race  age  time_in_hospital  num_lab_procedures  num_procedures  \
# 0        Caucasian    0                 1                  41               0
# 1        Caucasian    1                 3                  59               0
# 2  AfricanAmerican    2                 2                  11               5
# 3        Caucasian    3                 2                  44               1
# 4        Caucasian    4                 1                  51               0
#
#    num_medications  number_outpatient  number_emergency  number_inpatient  \
# 0                1                  0                 0                 0
# 1               18                  0                 0                 0
# 2               13                  2                 0                 1
# 3               16                  0                 0                 0
# 4                8                  0                 0                 0
#
#    number_diagnoses  ...  pt_admission_source_2_ct  pt_admission_source_3_ct  \
# 0                 1  ...                         0                         0
# 1                 9  ...                         0                         0
# 2                 6  ...                         0                         0
# 3                 7  ...                         0                         0
# 4                 5  ...                         0                         0
#
#    pt_time_tot  pt_lab_procedure_tot  pt_procedure_tot  pt_med_tot  \
# 0            1                    41                 0           1
# 1            3                    59                 0          18
# 2            2                    11                 5          13
# 3            2                    44                 1          16
# 4            1                    51                 0           8
#
#    pt_outp_tot  pt_inp_tot  pt_ER_tot  pt_diag_tot
# 0            0           0          0            1
# 1            0           0          0            9
# 2            2           1          0            6
# 3            0           0          0            7
# 4            0           0          0            5
#
# [5 rows x 90 columns]

# %%
print(data.info())
print(data.describe())
print(data.head())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 97108 entries, 0 to 97107
# Data columns (total 90 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   race                       97108 non-null  object
#  1   age                        97108 non-null  int64
#  2   time_in_hospital           97108 non-null  int64
#  3   num_lab_procedures         97108 non-null  int64
#  4   num_procedures             97108 non-null  int64
#  5   num_medications            97108 non-null  int64
#  6   number_outpatient          97108 non-null  int64
#  7   number_emergency           97108 non-null  int64
#  8   number_inpatient           97108 non-null  int64
#  9   number_diagnoses           97108 non-null  int64
#  10  max_glu_serum              97108 non-null  int64
#  11  A1Cresult                  97108 non-null  int64
#  12  metformin                  97108 non-null  int64
#  13  glimepiride                97108 non-null  int64
#  14  glipizide                  97108 non-null  int64
#  15  glyburide                  97108 non-null  int64
#  16  pioglitazone               97108 non-null  int64
#  17  rosiglitazone              97108 non-null  int64
#  18  insulin                    97108 non-null  int64
#  19  diabetesMed                97108 non-null  int64
#  20  readmitted                 97108 non-null  object
#  21  admission_urg_ind          97108 non-null  int64
#  22  admission_nurg_ind         97108 non-null  int64
#  23  admission_none_ind         97108 non-null  int64
#  24  discharge_shortterm_ind    97108 non-null  int64
#  25  discharge_longterm_ind     97108 non-null  int64
#  26  discharge_none_ind         97108 non-null  int64
#  27  admission_source_1         97108 non-null  int64
#  28  admission_source_2         97108 non-null  int64
#  29  admission_source_3         97108 non-null  int64
#  30  caucasian_ind              97108 non-null  int64
#  31  africanamerican_ind        97108 non-null  int64
#  32  hispanic_ind               97108 non-null  int64
#  33  asian_ind                  97108 non-null  int64
#  34  otherrace_ind              97108 non-null  int64
#  35  female_ind                 97108 non-null  int64
#  36  male_ind                   97108 non-null  int64
#  37  readmit_diag_1             97108 non-null  int64
#  38  readmit_diag_2             97108 non-null  int64
#  39  readmit_diag_3             97108 non-null  int64
#  40  readmit_diag_4             97108 non-null  int64
#  41  readmit_diag_5             97108 non-null  int64
#  42  readmit_diag_6             97108 non-null  int64
#  43  readmit_diag_7             97108 non-null  int64
#  44  readmit_diag_8             97108 non-null  int64
#  45  readmit_diag_9             97108 non-null  int64
#  46  readmit_diag_10            97108 non-null  int64
#  47  readmit_diag_11            97108 non-null  int64
#  48  readmit_diag_12            97108 non-null  int64
#  49  readmit_diag_13            97108 non-null  int64
#  50  pt_risk_diag_ct            97108 non-null  int64
#  51  pt_diag_ct                 97108 non-null  int64
#  52  d_external_index           97108 non-null  int64
#  53  d_supplementary_index      97108 non-null  int64
#  54  d_infect_ind               97108 non-null  int64
#  55  d_neoplasm_ind             97108 non-null  int64
#  56  d_endocrine_ind            97108 non-null  int64
#  57  d_blood_ind                97108 non-null  int64
#  58  d_mental_ind               97108 non-null  int64
#  59  d_nervous_ind              97108 non-null  int64
#  60  d_circulatory_ind          97108 non-null  int64
#  61  d_respiratory_ind          97108 non-null  int64
#  62  d_digestive_ind            97108 non-null  int64
#  63  d_genitourinary_ind        97108 non-null  int64
#  64  d_pegnancy_ind             97108 non-null  int64
#  65  d_skin_ind                 97108 non-null  int64
#  66  d_musculo_ind              97108 non-null  int64
#  67  d_congenital_ind           97108 non-null  int64
#  68  d_perinatal_ind            97108 non-null  int64
#  69  d_symptoms_ind             97108 non-null  int64
#  70  d_injury_ind               97108 non-null  int64
#  71  dia_med_change_ind         97108 non-null  int64
#  72  dia_med_nochange_ind       97108 non-null  int64
#  73  pt_admission_urg_ct        97108 non-null  int64
#  74  admission_nurg_ct          97108 non-null  int64
#  75  admission_none_ct          97108 non-null  int64
#  76  pt_discharge_shortterm_ct  97108 non-null  int64
#  77  pt_discharge_longterm_ct   97108 non-null  int64
#  78  pt_discharge_none_ct       97108 non-null  int64
#  79  pt_admission_source_1_ct   97108 non-null  int64
#  80  pt_admission_source_2_ct   97108 non-null  int64
#  81  pt_admission_source_3_ct   97108 non-null  int64
#  82  pt_time_tot                97108 non-null  int64
#  83  pt_lab_procedure_tot       97108 non-null  int64
#  84  pt_procedure_tot           97108 non-null  int64
#  85  pt_med_tot                 97108 non-null  int64
#  86  pt_outp_tot                97108 non-null  int64
#  87  pt_inp_tot                 97108 non-null  int64
#  88  pt_ER_tot                  97108 non-null  int64
#  89  pt_diag_tot                97108 non-null  int64
# dtypes: int64(88), object(2)
# memory usage: 66.7+ MB
# None
#                 age  time_in_hospital  num_lab_procedures  num_procedures  \
# count  97108.000000      97108.000000        97108.000000    97108.000000
# mean       6.072991          4.381328           42.882183        1.335245
# std        1.594832          2.969928           19.629838        1.700799
# min        0.000000          1.000000            1.000000        0.000000
# 25%        5.000000          2.000000           31.000000        0.000000
# 50%        6.000000          4.000000           44.000000        1.000000
# 75%        7.000000          6.000000           57.000000        2.000000
# max        9.000000         14.000000          132.000000        6.000000
#
#        num_medications  number_outpatient  number_emergency  number_inpatient  \
# count     97108.000000       97108.000000      97108.000000      97108.000000
# mean         15.983791           0.373285          0.201981          0.638475
# std           8.086448           1.274694          0.947391          1.268998
# min           1.000000           0.000000          0.000000          0.000000
# 25%          10.000000           0.000000          0.000000          0.000000
# 50%          15.000000           0.000000          0.000000          0.000000
# 75%          20.000000           0.000000          0.000000          1.000000
# max          81.000000          42.000000         76.000000         21.000000
#
#        number_diagnoses  max_glu_serum  ...  pt_admission_source_2_ct  \
# count      97108.000000   97108.000000  ...              97108.000000
# mean           7.418709       0.091177  ...                  0.000525
# std            1.933682       0.429516  ...                  0.022911
# min            1.000000       0.000000  ...                  0.000000
# 25%            6.000000       0.000000  ...                  0.000000
# 50%            8.000000       0.000000  ...                  0.000000
# 75%            9.000000       0.000000  ...                  0.000000
# max           16.000000       3.000000  ...                  1.000000
#
#        pt_admission_source_3_ct   pt_time_tot  pt_lab_procedure_tot  \
# count              97108.000000  97108.000000          97108.000000
# mean                   0.141193     10.246015             97.224976
# std                    0.743272     12.911727            113.313749
# min                    0.000000      1.000000              1.000000
# 25%                    0.000000      3.000000             41.000000
# 50%                    0.000000      6.000000             62.000000
# 75%                    0.000000     12.000000            114.000000
# max                   22.000000    180.000000           1593.000000
#
#        pt_procedure_tot    pt_med_tot   pt_outp_tot    pt_inp_tot  \
# count      97108.000000  97108.000000  97108.000000  97108.000000
# mean           2.720867     37.300356      1.154375      3.449551
# std            3.780463     45.640068      4.512179     14.230609
# min            0.000000      1.000000      0.000000      0.000000
# 25%            0.000000     13.000000      0.000000      0.000000
# 50%            2.000000     23.000000      0.000000      0.000000
# 75%            4.000000     43.000000      0.000000      2.000000
# max           51.000000    559.000000    146.000000    382.000000
#
#           pt_ER_tot   pt_diag_tot
# count  97108.000000  97108.000000
# mean       1.092577     17.268371
# std        8.369368     19.634131
# min        0.000000      1.000000
# 25%        0.000000      7.000000
# 50%        0.000000      9.000000
# 75%        0.000000     18.000000
# max      313.000000    272.000000
#
# [8 rows x 88 columns]
#               race  age  time_in_hospital  num_lab_procedures  num_procedures  \
# 0        Caucasian    0                 1                  41               0
# 1        Caucasian    1                 3                  59               0
# 2  AfricanAmerican    2                 2                  11               5
# 3        Caucasian    3                 2                  44               1
# 4        Caucasian    4                 1                  51               0
#
#    num_medications  number_outpatient  number_emergency  number_inpatient  \
# 0                1                  0                 0                 0
# 1               18                  0                 0                 0
# 2               13                  2                 0                 1
# 3               16                  0                 0                 0
# 4                8                  0                 0                 0
#
#    number_diagnoses  ...  pt_admission_source_2_ct  pt_admission_source_3_ct  \
# 0                 1  ...                         0                         0
# 1                 9  ...                         0                         0
# 2                 6  ...                         0                         0
# 3                 7  ...                         0                         0
# 4                 5  ...                         0                         0
#
#    pt_time_tot  pt_lab_procedure_tot  pt_procedure_tot  pt_med_tot  \
# 0            1                    41                 0           1
# 1            3                    59                 0          18
# 2            2                    11                 5          13
# 3            2                    44                 1          16
# 4            1                    51                 0           8
#
#    pt_outp_tot  pt_inp_tot  pt_ER_tot  pt_diag_tot
# 0            0           0          0            1
# 1            0           0          0            9
# 2            2           1          0            6
# 3            0           0          0            7
# 4            0           0          0            5
#
# [5 rows x 90 columns]

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import classification_report, confusion_matrix, mean_squared_error, roc_curve, auc, accuracy_score

#  data is already loaded into 'data'
# and that the target column is named 'readmitted' or similar
# Replace 'readmitted' below with your actual target column name

# Check unique values in your target column
print(data['readmitted'].value_counts())
# Out:
# readmitted
# NO     51018
# >30    34964
# <30    11126
# Name: count, dtype: int64

# %%
# If target is categorical like '<30', '>30', 'NO', convert to binary
data['readmitted_binary'] = data['readmitted'].apply(lambda x: 1 if x == '<30' else 0)

# Prepare features and target
X = data.drop(['readmitted', 'readmitted_binary'], axis=1)
y = data['readmitted_binary']

# %%
X['strat_col'] = X['race'].astype(str) + "_" + data['readmitted_binary'].astype(str)
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.2, stratify = X['strat_col'], random_state = 42)
X_train = X_train.drop(columns = ['strat_col' , 'race'])
X_test = X_test.drop(columns = ['strat_col' , 'race'])

# %%
# Scale features
scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test)

# %%
# Train logistic regression model
model = LogisticRegression(max_iter=1000)
model.fit(X_train_scaled, y_train)
# Out:
# LogisticRegression(max_iter=1000)

# %%
#setting prediction threshold at 0.12
probs = model.predict_proba(X_test_scaled)
y_pred = (probs[:, 1]>=0.5)

# %%
# --- Evaluate Model ---
#y_pred = model.predict(X_test)

mse = mean_squared_error(y_test, y_pred)
acc = accuracy_score(y_test, y_pred)
false_pos_rate, true_pos_rate, thresholds = roc_curve(y_test, probs[:,1])
roc_auc = auc(false_pos_rate, true_pos_rate)

roc_data = pd.DataFrame({'X': false_pos_rate.tolist(), 'Y': true_pos_rate.tolist()})
roc_data.to_csv('./figs/plot_data/roc_curve_logreg.csv', index=False)
    

print("Confusion Matrix:")
print(confusion_matrix(y_test, y_pred))
print("\nClassification Report:")
print(classification_report(y_test, y_pred))
print("Mean squared error = ",mse)
print("Accuracy = ",acc)
print("ROC AUC score = ",roc_auc)

plt.figure(figsize = (6,5))
plt.plot([0,1], [0,1], '--', lw=1)
plt.plot(false_pos_rate, true_pos_rate)
plt.xlabel('False positive rate', fontsize=13)
plt.ylabel('True positive rate', fontsize=13)
plt.title('Logistic regression')
plt.show()
# Out:
# Confusion Matrix:
# [[17074   123]
#  [ 2146    79]]
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.89      0.99      0.94     17197
#            1       0.39      0.04      0.07      2225
#
#     accuracy                           0.88     19422
#    macro avg       0.64      0.51      0.50     19422
# weighted avg       0.83      0.88      0.84     19422
#
# Mean squared error =  0.11682627947688189
# Accuracy =  0.8831737205231182
# ROC AUC score =  0.7193233729687631

# %%
# Compute confusion matrix
cm = confusion_matrix(y_test, y_pred)

# Plot confusion matrix heatmap
plt.figure(figsize=(6, 5))

sns.heatmap(cm, annot=True, cmap='crest', fmt='d')
plt.xlabel('Predicted')
plt.ylabel('Actual')
plt.title('Confusion Matrix - Logistic regression (processed)')

plt.savefig('./figs/conf_mat_log_2.png')
plt.show()

# Print confusion matrix and classification report for detailed metrics
print("Confusion Matrix:\n", cm)
# Out:
# Confusion Matrix:
#  [[17074   123]
#  [ 2146    79]]
